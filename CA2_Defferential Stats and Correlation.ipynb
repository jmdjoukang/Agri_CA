# %% [raw]
# # There are a number of repositories that may have data sets relevant to the CAP, including:
#
# 1. The European Union&#39;s official website: The EU&#39;s official website (https://ec.europa.eu/)
# may have data sets and other information related to the CAP.
# 2. Eurostat: Eurostat is the statistical office of the European Union and maintains a wide
# range of data on the EU and its member states, including data on the CAP. You can
# access Eurostat&#39;s data at https://ec.europa.eu/eurostat/data/database.
# 3. The Organisation for Economic Co-operation and Development (OECD): The OECD
# maintains a wide range of data on its member countries, including data on the agricultural
# sector. You can access the OECD&#39;s data at https://data.oecd.org/.
# 4. National statistical offices: Many national statistical offices within the EU also maintain
# data on the agricultural sector, including data on the CAP. You can access data from
# individual national statistical offices through their websites.

# %%
#importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns
from scipy import stats
from scipy.stats import wilcoxon
from scipy.stats import skew
from scipy.stats import kurtosis
import pingouin as pg
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn import linear_model
import statsmodels.api as sm
from sklearn.model_selection import GridSearchCV

# %%
 #Importing Data From Excel (csv) file
taskdata = pd.read_csv('datajm.csv')

# %%
#Viewing the Dataset
taskdata.head()
# Out:
#    Year  Ireland % Change in Production  Spain% Change in Production  \
# 0  1991                       -3.959618                     1.140692
# 1  1992                        8.603737                    -8.430644
# 2  1993                       -0.447907                    -5.601966
# 3  1994                        3.585840                     5.461499
# 4  1995                        1.590633                     1.005087
#
#    France % Change in Production  Ireland % Change in Nutrient Balance  \
# 0                          -5.15                              0.000000
# 1                           3.09                              0.000000
# 2                          -1.33                             13.207547
# 3                           5.21                             11.666667
# 4                           4.91                              7.462687
#
#    Spain % Change in Nutrient Balance  France % Change in Nutrient Balance  \
# 0                           -3.333333                               -16.90
# 1                            0.000000                                 3.39
# 2                          -17.241379                               -16.39
# 3                           33.333333                                 3.92
# 4                            6.250000                                 3.77
#
#    Ireland % Change in Labor Input  Spain% Change in Labor Input  \
# 0                       -10.676569                     -6.012607
# 1                        -1.067887                     -2.749593
# 2                        -2.852737                     -4.196357
# 3                        -3.055556                     -1.106801
# 4                        -5.157593                     -1.098546
#
#    France % Change in Labor Input
# 0                       -4.381590
# 1                       -4.306684
# 2                       -5.325858
# 3                       -3.511802
# 4                       -2.983294

# %%
#Descriptive Statistics
taskdata.describe()
# Out:
#               Year  Ireland % Change in Production  \
# count    27.000000                       27.000000
# mean   2004.000000                        2.022503
# std       7.937254                        7.444135
# min    1991.000000                      -18.378715
# 25%    1997.500000                       -3.440703
# 50%    2004.000000                        1.590633
# 75%    2010.500000                        5.191712
# max    2017.000000                       16.114216
#
#        Spain% Change in Production  France % Change in Production  \
# count                    27.000000                      27.000000
# mean                      1.960239                       1.023333
# std                       5.796599                       4.235299
# min                      -8.760875                      -7.520000
# 25%                      -1.120144                      -1.715000
# 50%                       1.467731                       1.550000
# 75%                       5.764819                       3.770000
# max                      14.293188                       9.630000
#
#        Ireland % Change in Nutrient Balance  \
# count                             27.000000
# mean                               2.111365
# std                               17.386102
# min                              -36.771300
# 25%                               -7.920489
# 50%                                1.557632
# 75%                               12.423291
# max                               43.589744
#
#        Spain % Change in Nutrient Balance  \
# count                           27.000000
# mean                             2.892878
# std                             15.101640
# min                            -22.318841
# 25%                             -7.939710
# 50%                              0.746269
# 75%                             12.225443
# max                             37.282230
#
#        France % Change in Nutrient Balance  Ireland % Change in Labor Input  \
# count                            27.000000                        27.000000
# mean                              0.400370                        -2.114452
# std                              24.668454                         5.067113
# min                             -52.140000                       -10.716366
# 25%                             -16.645000                        -4.106574
# 50%                               3.390000                        -1.531292
# 75%                              19.005000                        -0.003055
# max                              54.040000                        13.037543
#
#        Spain% Change in Labor Input  France % Change in Labor Input
# count                     27.000000                       27.000000
# mean                      -1.291660                       -2.309578
# std                        3.613247                        1.088375
# min                       -8.926314                       -5.325858
# 25%                       -3.935785                       -2.554136
# 50%                       -1.170356                       -2.371122
# 75%                        0.600142                       -1.552855
# max                        7.312751                       -0.832266

# %%
#Spliting Dataset into Vaiables
x = taskdata.iloc[:,1]
y = taskdata.iloc[:,2]
z = taskdata.iloc[:,3]
p = taskdata.iloc[:,4]
q = taskdata.iloc[:,5]
r = taskdata.iloc[:,6]
j = taskdata.iloc[:,7]
k = taskdata.iloc[:,8]
l = taskdata.iloc[:,9]

# %%
#Computing Skewness
for col in taskdata:
    print(col)
    print(skew(taskdata[col]))
    
    plt.figure()
    sns.distplot(taskdata[col])
    plt.show()
# Out:
# Year
# 0.0
# C:\Users\jmdjo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Ireland % Change in Production
# -0.25904688514299185
# C:\Users\jmdjo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Spain% Change in Production
# 0.06983821768509922
# C:\Users\jmdjo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# France % Change in Production
# -0.12588591799043794
# C:\Users\jmdjo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Ireland % Change in Nutrient Balance
# -0.08323265364353605
# C:\Users\jmdjo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Spain % Change in Nutrient Balance
# 0.5218760794429442
# C:\Users\jmdjo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# France % Change in Nutrient Balance
# 0.030934737067203028
# C:\Users\jmdjo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Ireland % Change in Labor Input
# 0.4864590079965506
# C:\Users\jmdjo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Spain% Change in Labor Input
# 0.24965755965794614
# C:\Users\jmdjo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# France % Change in Labor Input
# -1.0031011305759847
# C:\Users\jmdjo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Computing Kurtosis
for col in taskdata:
    print(col)
    print(kurtosis(taskdata[col]))
# Out:
# Year
# -1.2032967032967032
# Ireland % Change in Production
# 0.6870645241773632
# Spain% Change in Production
# -0.19461395566756323
# France % Change in Production
# -0.5167448084946358
# Ireland % Change in Nutrient Balance
# 0.7123391583171998
# Spain % Change in Nutrient Balance
# -0.24566089464822793
# France % Change in Nutrient Balance
# -0.3125633364343643
# Ireland % Change in Labor Input
# 1.4946699239889467
# Spain% Change in Labor Input
# 0.06882370896729695
# France % Change in Labor Input
# 0.8808588615279809

# %%
#Paired Sample t-test Analysis to Compare Irelant and Spain with Regard to % Change in Production
#H0: M0=M1
#H1: M0 not equal to M1
#Alpha=0.05
stats.ttest_rel(x,y)
# Out:
# Ttest_relResult(statistic=0.048640114225444474, pvalue=0.9615778230515272)

# %%
#Paired Sample t-test Analysis to Compare Ireland and Spain with Regard to % Change in Nutrient Balance
#H0: M0=HM1
#H1: M0 Note Equal to M1
#Alpha=0.05
stats.ttest_rel(p,q)
# Out:
# Ttest_relResult(statistic=-0.209917091401485, pvalue=0.8353686575553475)

# %%
#Paired Sample t-test Analysis to Compare Ireland and Spain with Regard to % Change in Labor Input
#H0: M0=HM1
#H1: M0 Note Equal to M1
#Alpha=0.05
stats.ttest_rel(j,k)
# Out:
# Ttest_relResult(statistic=-0.7543805184346148, pvalue=0.45739946629591544)

# %%
#Independent Sample ttest Anlysis to Compare Ireland and Spain with Regard to % Change in Production
#H0: M0=M1
#H1: M0 not equal to M1
#Alpha=0.05
stats.ttest_ind(x,y)
# Out:
# Ttest_indResult(statistic=0.03429139216001633, pvalue=0.9727760831845589)

# %%
#Indpendent Sample ttest Analaysis to Compare Ireland and Spain with Regard to % Change in Nutrient Balance
#H0: M0=M1
#H1: M0 not equal to M1
#Alpha=0.05
stats.ttest_ind(p,q)
# Out:
# Ttest_indResult(statistic=-0.17633655389634448, pvalue=0.8607145176558175)

# %%
#Independent Sample ttest Anlysis to Compare Ireland and Spain with Regard to % Labor Input
#H0: M0=M1
#H1: M0 not equal to M1
#Alpha=0.05
stats.ttest_ind(j,k)
# Out:
# Ttest_indResult(statistic=-0.6869762511163178, pvalue=0.49515013906293703)

# %%
#One sample ttest Analysis to Test Satatistical Significance in the Difference between Spain's Average % Change in Production and the Ireland mean % Change in Production
#H0: M=1.96
#H1: M not equal to 1.96
#Alpha=0.05
stats.ttest_1samp(x, 1.96)
# Out:
# Ttest_1sampResult(statistic=0.043628599234602654, pvalue=0.9655338005799113)

# %%
#One sample ttest Analysis to Test Satatistical Significance in the Difference between Spain's Average % Change in Nutrient Balance and the Ireland mean % Change in Nutrient Balance
#H0: M=1.96
#H1: M not equal to 2.89
#Alpha=0.05
stats.ttest_1samp(p, 2.89)
# Out:
# Ttest_1sampResult(statistic=-0.2327092432964251, pvalue=0.817809371488665)

# %%
#One sample ttest Analysis to Test Satatistical Significance in the Difference between Spain's Average % Change in Production and the Ireland mean % Change in Production
#H0: M=1.96
#H1: M not equal to 1.96
#Alpha=0.05
stats.ttest_1samp(j, -1.29)
# Out:
# Ttest_1sampResult(statistic=-0.8454475876207341, pvalue=0.4055745209750492)

# %%
#Wilcoxon test to Compare Ireland and Spain with Regard to % Change in Production
wilcoxon(x,y)
# Out:
# WilcoxonResult(statistic=171.0, pvalue=0.6654143977847693)

# %%
#Wilcoxon test to Compare Ireland and Spain with Regard to % Change in Nutrient Balance
wilcoxon(p,q)
# Out:
# WilcoxonResult(statistic=157.0, pvalue=0.6384532010547104)

# %%
#Wilcoxon test to Compare Ireland and Spain with Regard to % Change in Labor Input
wilcoxon(j,k)
# Out:
# WilcoxonResult(statistic=156.0, pvalue=0.4278798079182492)

# %%
#ANOVA to compare Ireland, Spain and Frnance with Regards to % Change in Production and Nutrient Balance
#H0: M1=M2=M3
#H1: M1 not equal to M2 not equal to M3
#Import ANOVA Data
nd = pd.read_csv('datajm_1.csv')

# %%
#Viewing ANOVA Data
nd
# Out:
#     % Change in Production  % Change in Nutrient Balance  \
# 0                -3.959618                      0.000000
# 1                 8.603737                      0.000000
# 2                -0.447907                     13.207547
# 3                 3.585840                     11.666667
# 4                 1.590633                      7.462687
# ..                     ...                           ...
# 76               -3.130000                     26.380000
# 77                1.550000                     -0.340000
# 78               -0.160000                     26.010000
# 79               -6.280000                     27.350000
# 80                3.780000                    -29.050000
#
#     % Change in Labor Input  Country
# 0                -10.676569        1
# 1                 -1.067887        1
# 2                 -2.852737        1
# 3                 -3.055556        1
# 4                 -5.157593        1
# ..                      ...      ...
# 76                -0.913474        3
# 77                -0.832266        3
# 78                -1.665591        3
# 79                -1.141019        3
# 80                -0.962930        3
#
# [81 rows x 4 columns]

# %%
#Generating BoxPlots for the ANOVA Data
nd.boxplot('% Change in Production', by = 'Country')
# Out:
# <AxesSubplot:title={'center':'% Change in Production'}, xlabel='Country'>

# %%
nd.boxplot('% Change in Nutrient Balance', by = 'Country')
# Out:
# <AxesSubplot:title={'center':'% Change in Nutrient Balance'}, xlabel='Country'>

# %%
nd.boxplot('% Change in Labor Input', by='Country')
# Out:
# <AxesSubplot:title={'center':'% Change in Labor Input'}, xlabel='Country'>

# %%
#ANOVA 1: For Production
anova = pg.anova(dv='% Change in Production', between='Country', data=nd, detailed=True)

# %%
anova
# Out:
#     Source           SS  DF         MS         F     p-unc       np2
# 0  Country    16.920096   2   8.460048  0.237301  0.789321  0.006048
# 1   Within  2780.790267  78  35.651157       NaN       NaN       NaN

# %%
#ANOVA 2: For Nutrient Balance
anova2 = pg.anova(dv='% Change in Nutrient Balance', between='Country', data=nd, detailed=True)

# %%
anova2
# Out:
#     Source            SS  DF          MS         F     p-unc       np2
# 0  Country     87.757712   2   43.878856  0.115585  0.890997  0.002955
# 1   Within  29610.586867  78  379.622909       NaN       NaN       NaN

# %%
#ANOVA 3: For Labor Input
anova3= pg.anova(dv='% Change in Labor Input', between='Country', data=nd, detailed=True)

# %%
anova3
# Out:
#     Source           SS  DF         MS         F    p-unc      np2
# 0  Country    15.760982   2   7.880491  0.592284  0.55553  0.01496
# 1   Within  1037.809410  78  13.305249       NaN      NaN      NaN

# %%
#Correlation Matrix
sns.heatmap(taskdata.corr(), annot=True)
plt.show()
